# %%
import pandas as pd
sample_df=pd.read_csv("examples/sample.csv")#index ya name ni dein ge to yy first row ko lable k lea use kar le ga
print(sample_df)
# Out:
#   studentid         name   chimestry   physics   english   math
# 0       A01     arif ali          20        30        40     50
# 1       A02  kamran khan          30        40        50     60
# 2       A03   imran ali           40        50        60     70
# 3       A04  kashif khan          50        60        70     80

# %%
sample_df=pd.read_csv("examples/sample.csv"
                      ,names=["id","na","ch","ph","en","math"])#data k name kudh dea hain
print(sample_df)
print("\n")
sample_df=pd.read_csv("examples/sample.csv",skiprows=1
                      ,names=["id","na","ch","ph","en","math"])
print(sample_df)
print("\n")
sample_df=pd.read_csv("examples/sample.csv",header=None)#header=None karne paar first row ko name ni le ga
print(sample_df)
# Out:
#           id           na          ch        ph        en   math
# 0  studentid         name   chimestry   physics   english   math
# 1        A01     arif ali          20        30        40     50
# 2        A02  kamran khan          30        40        50     60
# 3        A03   imran ali           40        50        60     70
# 4        A04  kashif khan          50        60        70     80
#
#
#     id           na  ch  ph  en  math
# 0  A01     arif ali  20  30  40    50
# 1  A02  kamran khan  30  40  50    60
# 2  A03   imran ali   40  50  60    70
# 3  A04  kashif khan  50  60  70    80
#
#
#            0            1           2         3         4      5
# 0  studentid         name   chimestry   physics   english   math
# 1        A01     arif ali          20        30        40     50
# 2        A02  kamran khan          30        40        50     60
# 3        A03   imran ali           40        50        60     70
# ...

# %%
sample_df=pd.read_csv("examples/ex1.csv")
print(sample_df)
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
s2_dr=pd.read_csv("examples/sample2.csv")
print(s2_dr)
print("\n")
s3_dr=pd.read_csv("examples/sample2.csv",index_col=["key1"])
print(s3_dr)
s3_dr=pd.read_csv("examples/sample2.csv",index_col=["key1","key2"])
print(s3_dr)
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16
#
#
#      key2  value1  value2
# key1
# one     a       1       2
# one     b       3       4
# one     c       5       6
# one     d       7       8
# two     a       9      10
# two     b      11      12
# two     c      13      14
# two     d      15      16
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %% [markdown]
# # Handling missing values

# %%
s4_df=pd.read_csv("examples/sample3.csv")
print(s4_df)
print()
sentinels={"message":["foo","NaN"]}
#message mein "foo" ki value "NaN" kar de kisi bhe value ko change karne k lae nan karne k kea "NA" bhe likh sakte hain
pd.read_csv("examples/sample3.csv",na_values=sentinels)
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     NaN

# %% [markdown]
# pd.read_csv("datasets/train.csv")

# %%
pd.read_csv("datasets/train.csv",nrows=500)
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0              842     0          2.2         0   1       0           7
# 1             1021     1          0.5         1   0       1          53
# 2              563     1          0.5         1   2       1          41
# 3              615     1          2.5         0   0       0          10
# 4             1821     1          1.2         0  13       1          44
# 5             1859     0          0.5         1   3       0          22
# 6             1821     0          1.7         0   4       1          10
# 7             1954     0          0.5         1   0       0          24
# 8             1445     1          0.5         0   0       0          53
# 9              509     1          0.6         1   2       1           9
# 10             769     1          2.9         1   0       0           9
# 11            1520     1          2.2         0   5       1          33
# ...

# %%
#kisi bhare data ko DataFrame mein bhot se hise banane ko pandas mein chunks khete hain
#ex:2000 rows k date ko 20 hiso mein karna yani 20 chunks banana
#chunksize=       yy cammand use hoti hai

# %%
chunks=pd.read_csv("datasets/train.csv",chunksize=200)
print(chunks)#print ni ho ga detail de ga loop banana ho ga.

# %%
chunks=pd.read_csv("datasets/train.csv",chunksize=200)
for chunk in chunks:
    print(type(chunk),len(chunk))
    print(chunk)
# Out:
# <class 'pandas.core.frame.DataFrame'> 200
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0              842     0          2.2         0   1       0           7
# 1             1021     1          0.5         1   0       1          53
# 2              563     1          0.5         1   2       1          41
# 3              615     1          2.5         0   0       0          10
# 4             1821     1          1.2         0  13       1          44
# 5             1859     0          0.5         1   3       0          22
# 6             1821     0          1.7         0   4       1          10
# 7             1954     0          0.5         1   0       0          24
# 8             1445     1          0.5         0   0       0          53
# 9              509     1          0.6         1   2       1           9
# 10             769     1          2.9         1   0       0           9
# ...

# %%
print(chunk.head())
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1800           1358     0          1.7         0   0       0          60
# 1801           1035     1          1.9         1   8       0          11
# 1802           1289     0          0.8         1   3       1          16
# 1803           1445     0          2.2         1   2       0          37
# 1804           1702     1          2.3         1  12       1          47
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1800    0.6        147        3  ...        889      1635   440    14    10
# 1801    1.0        173        6  ...        831      1709  2002    17     8
# 1802    0.9        161        6  ...        713      1854  3167    14     8
# 1803    0.4         82        2  ...        527      1393  3480    17    16
# 1804    0.6        107        2  ...       1284      1643   595    10     0
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
#chunks ko ham list mein save kar k us k ak ak hise par call kar k kam kar sakte hain

# %%
chunks=pd.read_csv("datasets/train.csv",chunksize=200)
chunkList=[]#list banai is se call kar k chunks k har hise par kam kar sakte hai
for chunk in chunks:
    #print(type(chunk),len(chunk))
    #print(chunk)
    #print(chunk.head())
    chunkList.append(chunk)
df=chunkList[2]#list mein se 2 num chunk ko call ki
df.head()#.head() se shuri ki 5 value aai ge or khali "df" se sari value aai gi
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 400           1266     0          1.9         1   0       1           7
# 401           1042     0          2.7         1  16       1          50
# 402           1479     0          0.5         0   8       0          19
# 403           1476     1          1.2         1   0       1          55
# 404           1552     1          2.2         0   6       1          13
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 400    0.2        184        3  ...        346      1468  2532    10     5
# 401    0.8         93        7  ...        727      1705  3215    18     0
# 402    0.6        156        3  ...        180      1476  3323    13    12
# 403    0.1        171        4  ...       1641      1666  1529    13     8
# 404    0.2        123        6  ...        269      1026  2403     9     2
#
#      talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
list(open("examples/ex3.txt"))
# Out:
# ['            A         B         C\n',
#  'aaa -0.264438 -1.026059 -0.619500\n',
#  'bbb  0.927272  0.302904 -0.032399\n',
#  'ccc -0.264273 -0.386314 -0.217601\n',
#  'ddd -0.871858 -0.348382  1.100491\n']

# %%
b=list(open("examples/ex3.txt"))
print(b)
bilal=pd.read_table("examples/ex3.txt",sep="\s+")
bilal
# Out:
# ['            A         B         C\n', 'aaa -0.264438 -1.026059 -0.619500\n', 'bbb  0.927272  0.302904 -0.032399\n', 'ccc -0.264273 -0.386314 -0.217601\n', 'ddd -0.871858 -0.348382  1.100491\n']
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: read_table is deprecated, use read_csv instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491

# %%
abs(bilal)#- ki value + mein aa gai
# Out:
#             A         B         C
# aaa  0.264438  1.026059  0.619500
# bbb  0.927272  0.302904  0.032399
# ccc  0.264273  0.386314  0.217601
# ddd  0.871858  0.348382  1.100491

# %%
df=pd.read_csv("examples/ex4.csv",skiprows=[0,2,3])
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df=pd.read_csv("examples/ex4.csv")
df
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make things more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
list(open("examples/ex4.csv"))
# Out:
# ['# hey!\n',
#  'a,b,c,d,message\n',
#  '# just wanted to make things more difficult for you\n',
#  '# who reads CSV files with computers, anyway?\n',
#  '1,2,3,4,hello\n',
#  '5,6,7,8,world\n',
#  '9,10,11,12,foo']
